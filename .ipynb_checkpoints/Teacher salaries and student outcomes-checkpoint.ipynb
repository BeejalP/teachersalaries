# %%
import pandas as pd
import numpy as np

# %%
# pip install pandas openpyxl xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load the entire Excel file
file_path = '/Users/beejalparekh/Desktop/Bootcamp/_DA_course/_DA-project_/Datasets/Eurydice/Open data_Teachers and school heads salaries and allowances_datasets_2022-2023.xlsx'
xls = pd.ExcelFile(file_path)

# Display sheet names
print(xls.sheet_names)
# Out:
# ['Cover', 'EurostatData', 'ind1', 'ind2', 'ind3', 'ind4', 'ind5', 'ind6', 'ind7', 'ind8', 'ind9', 'ind10', 'ind11', 'ind12', 'ind13', 'ind14', 'ind15', 'ind16', 'ind17', 'ind18', 'ind19_Year20_21', 'ind19_Year21_22', 'ind19_Year22_23', 'ind20', 'ind21', 'ind22', 'ind23_Year20_21', 'ind23_Year21_22', 'ind23_Year22_23', 'ind24', 'ind25', 'ind26']

# %%
# Average annual gross actual salaries of teachers (in PPS), by ISCED level, 2022/2023
avg_teacher_salary_pps = pd.read_excel(file_path, sheet_name='ind8')
avg_teacher_salary_pps.head()
# Out:
#    Indicator 8  \
# 0          NaN
# 1          NaN
# 2  ISCED level
# 3     ISCED 02
# 4      ISCED 1
#
#   Average annual gross actual salaries of teachers (in PPS), by ISCED level, 2022/2023  \
# 0                                                NaN
# 1                                                NaN
# 2                                          Age range
# 3                                        25-64 years
# 4                                        25-64 years
#
#      Unnamed: 2    Unnamed: 3    Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0           NaN           NaN           NaN        NaN        NaN
# 1           NaN           NaN           NaN        NaN        NaN
# 2         BE-FR         BE-DE         BE-NL         BG         CZ
# 3  46227.357025  43650.027882  46828.883371          :          :
# 4  44868.764138  44860.719174  46173.345949          :          :
#
#      Unnamed: 7    Unnamed: 8    Unnamed: 9  ... Unnamed: 31   Unnamed: 32  \
# ...

# %%
# Reset row 2 as column header
avg_teacher_salary_pps.columns = avg_teacher_salary_pps.iloc[2]  # Assign row 2 as column headers
avg_teacher_salary_pps = avg_teacher_salary_pps[3:].reset_index(drop=True)  # Remove the old header row
avg_teacher_salary_pps.head()
# Out:
# 2 ISCED level    Age range         BE-FR         BE-DE         BE-NL BG CZ  \
# 0    ISCED 02  25-64 years  46227.357025  43650.027882  46828.883371  :  :
# 1     ISCED 1  25-64 years  44868.764138  44860.719174  46173.345949  :  :
# 2    ISCED 24  25-64 years  43994.392437  45840.002366  46038.342303  :  :
# 3    ISCED 34  25-64 years  54953.944212  51308.420217  55285.169387  :  :
# 4    ISCED 02  25-34 years  36648.895723  36616.409537  38060.391909  :  :
#
# 2            DK            DE            EE  ... AL            BA CH  \
# 0   39134.90368             :  20107.483709  ...  :  15384.900486  :
# 1  47506.090248  59828.059887   25938.32275  ...  :  17455.802231  :
# 2  47781.931639  65801.127715   25938.32275  ...  :  17455.802231  :
# 3  55646.596957  68853.830448   25938.32275  ...  :  18189.651977  :
# 4  36125.196762             :             :  ...  :             :  :
#
# 2            IS LI            ME MK            NO            RS TR
# ...

# %%
# Teachers’ annual gross statutory salaries (in PPS) at different stages of the career, by ISCED level and qualification, 2022/2023
avg_teacher_salary_pps_by_stage = pd.read_excel(file_path, sheet_name='ind4')
avg_teacher_salary_pps_by_stage.head()
# Out:
#    Indicator 4  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4  ISCED level
#
#   Teachers’ annual gross statutory salaries (in PPS) at different stages of the career, by ISCED level and qualification, 2022/2023  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                      Qualification
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# 2                 NaN        NaN        NaN        NaN        NaN        NaN
# 3                 NaN        NaN        NaN        NaN        NaN        NaN
# 4  Salary progression      BE-FR      BE-DE      BE-NL         BG         CZ
#
# ...

# %%
# Reset row 4 as column header
avg_teacher_salary_pps_by_stage.columns = avg_teacher_salary_pps_by_stage.iloc[4]  # Assign row 4 as column headers
avg_teacher_salary_pps_by_stage = avg_teacher_salary_pps_by_stage[5:].reset_index(drop=True)  # Remove the old header row
avg_teacher_salary_pps_by_stage.head()
# Out:
# 4 ISCED level Qualification Salary progression         BE-FR         BE-DE  \
# 0    ISCED 02       Minimum    Starting salary  31809.028541  33710.302641
# 1     ISCED 1       Minimum    Starting salary  31809.028541  33710.302641
# 2    ISCED 24       Minimum    Starting salary  31809.028541  33710.302641
# 3    ISCED 34       Minimum    Starting salary  37186.434377  42238.572805
# 4    ISCED 02       Minimum     After 10 years  39739.164231  42170.313794
#
# 4         BE-NL            BG            CZ            DK            DE  ...  \
# 0  32610.716737  18511.364252  18610.740452  34939.659696             m  ...
# 1  32610.716737  18511.364252  19758.805609  40269.188966   51365.88044  ...
# 2  32610.716737  18511.364252  19758.805609  40447.680084  56787.339069  ...
# 3  32610.716737  18511.364252  19758.805609  37504.778502  58970.094654  ...
# 4  40893.446051  19096.275703   19154.56079  39605.070834             m  ...
#
# ...
